# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.applications import EfficientNetB0  # Replace ResNet50 with EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imblearn.over_sampling import SMOTE
from skimage.feature import hog
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import lime
from lime.lime_tabular import LimeTabularExplainer

# Data Loading with Augmentation
base_path = '../Database/'
data, labels = [], []

data_gen = ImageDataGenerator(
    rotation_range=30, width_shift_range=0.2, height_shift_range=0.2,
    shear_range=0.2, zoom_range=0.2, horizontal_flip=True,
    brightness_range=[0.8, 1.2], fill_mode='nearest'
)

# Load Data
def load_images_from_folder(folder, label):
    folder_path = os.path.join(base_path, folder)
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            continue
        img = cv2.resize(img, (128, 128))
        data.append(img)
        labels.append(label)

load_images_from_folder("Normal", "Normal")
for folder in ["Lung_Opacity", "Viral Pneumonia"]:
    load_images_from_folder(folder, "Lung_Disease")

data = np.array(data).astype('float32') / 255.0
labels = np.array(labels)

# Encode labels
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42, stratify=labels_encoded
)

# Extract HOG Features
def extract_hog_features(images):
    return np.array([hog(img, orientations=9, pixels_per_cell=(8, 8),
                          cells_per_block=(2, 2), visualize=False) for img in images])

X_train_hog = extract_hog_features(X_train)
X_test_hog = extract_hog_features(X_test)

# CNN Feature Extraction (EfficientNetB0)
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dropout(0.5)(x)

feature_extractor = Model(inputs=base_model.input, outputs=x)

def extract_cnn_features(images):
    images = np.repeat(images[..., np.newaxis], 3, axis=-1)  # Convert grayscale to RGB
    return feature_extractor.predict(images, verbose=0)

X_train_cnn = extract_cnn_features(X_train)
X_test_cnn = extract_cnn_features(X_test)

# Combine CNN + HOG Features
X_train_features = np.hstack((X_train_cnn, X_train_hog))
X_test_features = np.hstack((X_test_cnn, X_test_hog))

# Handle Imbalance Using SMOTE
smote = SMOTE(random_state=42)
X_train_features, y_train = smote.fit_resample(X_train_features, y_train)

# Feature Scaling
scaler = StandardScaler()
X_train_features = scaler.fit_transform(X_train_features)
X_test_features = scaler.transform(X_test_features)

# Model Training
model = tf.keras.Sequential([
    Dense(256, activation='relu', kernel_regularizer=l2(0.01), input_shape=(X_train_features.shape[1],)),
    Dropout(0.5),
    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), loss='binary_crossentropy', metrics=['accuracy'])

# Learning Rate Scheduler & Early Stopping
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train_features, y_train, validation_data=(X_test_features, y_test),
                    epochs=50, callbacks=[lr_scheduler, early_stopping], batch_size=32)

# Evaluation
y_pred = (model.predict(X_test_features) > 0.5).astype("int32")
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))

# LIME Explanation
# Modify LIME explanation
explainer = LimeTabularExplainer(
    X_train_features,
    feature_names=["Feature " + str(i) for i in range(X_train_features.shape[1])],
    class_names=["Normal", "Lung_Disease"],
    discretize_continuous=True
)

# Function to make LIME-compatible predictions
def lime_predict_fn(x):
    preds = model.predict(x)  # Model returns shape (n_samples, 1)
    return np.hstack([1 - preds, preds])  # Convert to shape (n_samples, 2)

# Explain a test instance
exp = explainer.explain_instance(X_test_features[0], lime_predict_fn, num_features=10)

# Show explanation
exp.as_pyplot_figure()
plt.show()

# Plot Training & Validation Graphs
def plot_training_history(history):
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
    plt.title('Model Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss', color='blue')
    plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
    plt.title('Model Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.show()

plot_training_history(history)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/50
# C:\Users\thebe\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7600 - loss: 7.0792 - val_accuracy: 0.8602 - val_loss: 5.7176 - learning_rate: 5.0000e-04
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8754 - loss: 5.3756 - val_accuracy: 0.8722 - val_loss: 4.3892 - learning_rate: 5.0000e-04
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9165 - loss: 3.9730 - val_accuracy: 0.8797 - val_loss: 3.3350 - learning_rate: 5.0000e-04
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9249 - loss: 2.9914 - val_accuracy: 0.8872 - val_loss: 2.5475 - learning_rate: 5.0000e-04
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9452 - loss: 2.2049 - val_accuracy: 0.8872 - val_loss: 1.9560 - learning_rate: 5.0000e-04
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9505 - loss: 1.6522 - val_accuracy: 0.8797 - val_loss: 1.6112 - learning_rate: 5.0000e-04
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9572 - loss: 1.3108 - val_accuracy: 0.8647 - val_loss: 1.3620 - learning_rate: 5.0000e-04
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9643 - loss: 1.0811 - val_accuracy: 0.8797 - val_loss: 1.1581 - learning_rate: 5.0000e-04
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9647 - loss: 0.8951 - val_accuracy: 0.8707 - val_loss: 1.0961 - learning_rate: 5.0000e-04
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9656 - loss: 0.7926 - val_accuracy: 0.8752 - val_loss: 1.0548 - learning_rate: 5.0000e-04
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9619 - loss: 0.7344 - val_accuracy: 0.8737 - val_loss: 1.0107 - learning_rate: 5.0000e-04
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9597 - loss: 0.6748 - val_accuracy: 0.8827 - val_loss: 0.9006 - learning_rate: 5.0000e-04
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9540 - loss: 0.6475 - val_accuracy: 0.8722 - val_loss: 0.8725 - learning_rate: 5.0000e-04
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9543 - loss: 0.6127 - val_accuracy: 0.8752 - val_loss: 0.8289 - learning_rate: 5.0000e-04
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9637 - loss: 0.5684 - val_accuracy: 0.8677 - val_loss: 0.8526 - learning_rate: 5.0000e-04
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9565 - loss: 0.5333 - val_accuracy: 0.8812 - val_loss: 0.7603 - learning_rate: 5.0000e-04
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9757 - loss: 0.4683 - val_accuracy: 0.8857 - val_loss: 0.7309 - learning_rate: 5.0000e-04
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9651 - loss: 0.4788 - val_accuracy: 0.8827 - val_loss: 0.7362 - learning_rate: 5.0000e-04
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9569 - loss: 0.5177 - val_accuracy: 0.8812 - val_loss: 0.7503 - learning_rate: 5.0000e-04
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9622 - loss: 0.4523 - val_accuracy: 0.8692 - val_loss: 0.7536 - learning_rate: 5.0000e-04
# Epoch 21/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9670 - loss: 0.4428 - val_accuracy: 0.8797 - val_loss: 0.6680 - learning_rate: 2.5000e-04
# Epoch 22/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9868 - loss: 0.3295 - val_accuracy: 0.8692 - val_loss: 0.6446 - learning_rate: 2.5000e-04
# Epoch 23/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9944 - loss: 0.2637 - val_accuracy: 0.8902 - val_loss: 0.5725 - learning_rate: 2.5000e-04
# Epoch 24/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9881 - loss: 0.2362 - val_accuracy: 0.8872 - val_loss: 0.5726 - learning_rate: 2.5000e-04
# Epoch 25/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9812 - loss: 0.2356 - val_accuracy: 0.8812 - val_loss: 0.5592 - learning_rate: 2.5000e-04
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9728 - loss: 0.2682 - val_accuracy: 0.8917 - val_loss: 0.6360 - learning_rate: 2.5000e-04
# Epoch 27/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9766 - loss: 0.2808 - val_accuracy: 0.8767 - val_loss: 0.6417 - learning_rate: 2.5000e-04
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9824 - loss: 0.2714 - val_accuracy: 0.8827 - val_loss: 0.6071 - learning_rate: 2.5000e-04
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9898 - loss: 0.2531 - val_accuracy: 0.8872 - val_loss: 0.5774 - learning_rate: 1.2500e-04
# Epoch 30/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9927 - loss: 0.2205 - val_accuracy: 0.8887 - val_loss: 0.5486 - learning_rate: 1.2500e-04
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9918 - loss: 0.1968 - val_accuracy: 0.8917 - val_loss: 0.5068 - learning_rate: 1.2500e-04
# Epoch 32/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9977 - loss: 0.1693 - val_accuracy: 0.8917 - val_loss: 0.5020 - learning_rate: 1.2500e-04
# Epoch 33/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9979 - loss: 0.1541 - val_accuracy: 0.8947 - val_loss: 0.4972 - learning_rate: 1.2500e-04
# Epoch 34/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9955 - loss: 0.1465 - val_accuracy: 0.8932 - val_loss: 0.4919 - learning_rate: 1.2500e-04
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9997 - loss: 0.1290 - val_accuracy: 0.8917 - val_loss: 0.4657 - learning_rate: 1.2500e-04
# Epoch 36/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9963 - loss: 0.1250 - val_accuracy: 0.8902 - val_loss: 0.4427 - learning_rate: 1.2500e-04
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9952 - loss: 0.1223 - val_accuracy: 0.8887 - val_loss: 0.4423 - learning_rate: 1.2500e-04
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9915 - loss: 0.1289 - val_accuracy: 0.8932 - val_loss: 0.4936 - learning_rate: 1.2500e-04
# Epoch 39/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9928 - loss: 0.1322 - val_accuracy: 0.8872 - val_loss: 0.4927 - learning_rate: 1.2500e-04
# Epoch 40/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9936 - loss: 0.1371 - val_accuracy: 0.8872 - val_loss: 0.4936 - learning_rate: 1.2500e-04
# Epoch 41/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9948 - loss: 0.1301 - val_accuracy: 0.8887 - val_loss: 0.4852 - learning_rate: 6.2500e-05
# Epoch 42/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9955 - loss: 0.1189 - val_accuracy: 0.8947 - val_loss: 0.4669 - learning_rate: 6.2500e-05
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       418
#            1       0.85      0.85      0.85       247
#
#     accuracy                           0.89       665
#    macro avg       0.88      0.88      0.88       665
# weighted avg       0.89      0.89      0.89       665
#
# Accuracy: 0.8887218045112782
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
